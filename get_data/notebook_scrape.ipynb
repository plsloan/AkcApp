# %% [markdown]
# # Imports

# %%
import json
import requests

from bs4 import BeautifulSoup

# %%
breeds_links = [
    'https://www.akc.org/dog-breeds/affenpinscher/',
    'https://www.akc.org/dog-breeds/afghan-hound/',
    'https://www.akc.org/dog-breeds/airedale-terrier/',
    'https://www.akc.org/dog-breeds/akita/',
    'https://www.akc.org/dog-breeds/alaskan-malamute/',
    'https://www.akc.org/dog-breeds/american-bulldog/',
    'https://www.akc.org/dog-breeds/american-english-coonhound/',
    'https://www.akc.org/dog-breeds/american-eskimo-dog/',
    'https://www.akc.org/dog-breeds/american-foxhound/',
    'https://www.akc.org/dog-breeds/american-hairless-terrier/',
    'https://www.akc.org/dog-breeds/american-leopard-hound/',
    'https://www.akc.org/dog-breeds/american-staffordshire-terrier/',
    'https://www.akc.org/dog-breeds/american-water-spaniel/',
    'https://www.akc.org/dog-breeds/anatolian-shepherd-dog/',
    'https://www.akc.org/dog-breeds/appenzeller-sennenhund/',
    'https://www.akc.org/dog-breeds/australian-cattle-dog/',
    'https://www.akc.org/dog-breeds/australian-kelpie/',
    'https://www.akc.org/dog-breeds/australian-shepherd/',
    'https://www.akc.org/dog-breeds/australian-stump-tail-cattle-dog/',
    'https://www.akc.org/dog-breeds/australian-terrier/',
    'https://www.akc.org/dog-breeds/azawakh/',
    'https://www.akc.org/dog-breeds/barbet/',
    'https://www.akc.org/dog-breeds/basenji/',
    'https://www.akc.org/dog-breeds/basset-fauve-de-bretagne/',
    'https://www.akc.org/dog-breeds/basset-hound/',
    'https://www.akc.org/dog-breeds/bavarian-mountain-scent-hound/',
    'https://www.akc.org/dog-breeds/beagle/',
    'https://www.akc.org/dog-breeds/bearded-collie/',
    'https://www.akc.org/dog-breeds/beauceron/',
    'https://www.akc.org/dog-breeds/bedlington-terrier/',
    'https://www.akc.org/dog-breeds/belgian-laekenois/',
    'https://www.akc.org/dog-breeds/belgian-malinois/',
    'https://www.akc.org/dog-breeds/belgian-sheepdog/',
    'https://www.akc.org/dog-breeds/belgian-tervuren/',
    'https://www.akc.org/dog-breeds/bergamasco-sheepdog/',
    'https://www.akc.org/dog-breeds/berger-picard/',
    'https://www.akc.org/dog-breeds/bernese-mountain-dog/',
    'https://www.akc.org/dog-breeds/bichon-frise/',
    'https://www.akc.org/dog-breeds/biewer-terrier/',
    'https://www.akc.org/dog-breeds/black-and-tan-coonhound/',
    'https://www.akc.org/dog-breeds/black-russian-terrier/',
    'https://www.akc.org/dog-breeds/bloodhound/',
    'https://www.akc.org/dog-breeds/bluetick-coonhound/',
    'https://www.akc.org/dog-breeds/boerboel/',
    'https://www.akc.org/dog-breeds/bohemian-shepherd/',
    'https://www.akc.org/dog-breeds/bolognese/',
    'https://www.akc.org/dog-breeds/border-collie/',
    'https://www.akc.org/dog-breeds/border-terrier/',
    'https://www.akc.org/dog-breeds/borzoi/',
    'https://www.akc.org/dog-breeds/boston-terrier/',
    'https://www.akc.org/dog-breeds/bouvier-des-flandres/',
    'https://www.akc.org/dog-breeds/boxer/',
    'https://www.akc.org/dog-breeds/boykin-spaniel/',
    'https://www.akc.org/dog-breeds/bracco-italiano/',
    'https://www.akc.org/dog-breeds/working-kelpie/',
    'https://www.akc.org/dog-breeds/xoloitzcuintli/',
    'https://www.akc.org/dog-breeds/yakutian-laika/',
    'https://www.akc.org/dog-breeds/yorkshire-terrier/'
]

# %% [markdown]
# # Functions

# %%
def get_breed_data(html_text):
    breed_name = html_text.find(
        'h1', {'class': 'page-header__title'})
        
    if breed_name is not None:
        breed_name = breed_name.text.strip()

        breed_attributes = extract_attributes(html_text, breed_name)
        breed_traits = extract_traits(html_text)

        breed_info = {'breed_name': breed_name,
                    'attributes': breed_attributes, 'traits': breed_traits}

        return breed_info
    else:
        return {}

# %%
def extract_attributes(html_text, breed_name=None):
    breed_tabs = html_text.find_all('div', {"class": "tabs__tab-panel"})
    breed_attributes = {}
    for tab in breed_tabs:
        attributes = tab.find_all('li', {'class': 'attribute-list__row'})
        for att in attributes:
            term = att.find(
                'span', {'class': 'attribute-list__term'})
            if term is not None:
                term = term.text.split(':')[0]
            else:
                raise Exception('Could not find term for breed: {}.'.format())
            description = att.find(
                'span', {'class': 'attribute-list__description'})
            if description is not None:
                description = description.text
                if term == 'Temperament':
                    description = description.split(', ')
                elif term == 'AKC Breed Popularity':
                    description = [int(i)
                                   for i in description.split() if i.isdigit()][0]
                elif term == 'Height':
                    description = parse_height(description)
                elif term == 'Weight':
                    description = parse_weight(description)
                elif term == 'Life Expectancy':
                    description = parse_life_expectancy(description)
            breed_attributes[term] = description

    return breed_attributes

# %%
def parse_height(text, breed_name=None):
    text = text.replace(' inches', '').replace('Minimum: ', '')
    text_split_comma = text.split(', ')
    text_split_semicolon = text.split('; ')

    try:
        # 1, 2, 3 pattern
        if 'up to ' in text:
            description = [0, float(text.replace('up to ', ''))]
        elif len(text_split_comma) > 1 and ', ' in text:
            description = {}
            try:
                for t in text_split_comma:
                    paren_start = t.index('(')
                    paren_end = t.index(')')
                    val = t[:paren_start-1]
                    val_split = val.split('-')
                    val_type = t[paren_start+1:paren_end]
                    if len(val_split) > 1:
                        val_array = [float(i) for i in val_split]
                        description[val_type] = val_array
                    elif len(val_split) == 1:
                        val = val_split[0]
                        description[val_type] = float(val)
                    else:
                        description[val_type] = -1
            except:
                return 'Could not find'
        elif len(text_split_semicolon) > 1 and '; ' in text:
            description = {}
            try:
                for t in text_split_semicolon:
                    paren_start = t.index('(')
                    paren_end = t.index(')')
                    val = t[:paren_start-1]
                    val_split = val.split('-')
                    val_type = t[paren_start+1:paren_end]
                    if len(val_split) > 1:
                        val_array = [float(i) for i in val_split]
                        description[val_type] = val_array
                    elif len(val_split) == 1:
                        val = val_split[0]
                        description[val_type] = float(val)
                    else:
                        description[val_type] = -1
            except:
                return 'Could not find'
        # no commas or semicolons in text
        else:
            text_split = text.split('-')

            if len(text_split) == 1:
                description = float(text_split[0])
            else:
                description = [float(i) for i in text_split]
    except:
        return 'Could not find'

    if breed_name is not None:
        print(breed_name)
        print('{} -> {}'.format(text, description))

    return description

# %%
def parse_weight(text, breed_name=None):
    print(breed_name)
    print(text)

    text = text.replace(' pounds', '').replace('Minimum: ', '')
    text_split_comma = text.split(', ')
    text_split_semicolon = text.split('; ')

    try:
        if 'proportionate to height' in text.lower():
            return 'Proportionate to height' 
        elif 'not exceeding ' in text.lower():
            text = text.replace('not exceeding ', '')
            return [0, float(text)]
        elif 'under ' in text.lower():
            text = text.replace('under ', '')
            return [0, float(text)]
        elif len(text_split_comma) > 1:
            description = {}
            try:
                for t in text_split_comma:
                    paren_start = t.index('(')
                    paren_end = t.index(')')
                    val = t[:paren_start-1]
                    val_split = val.split('-')
                    val_type = t[paren_start+1:paren_end]
                    if len(val_split) > 1:
                        val_array = [float(i) for i in val_split]
                        print(val_array)
                        description[val_type] = val_array
                    elif len(val_split) == 1:
                        val = val_split[0]
                        description[val_type] = float(val)
                    else:
                        description[val_type] = -1
            except:
                return 'Could not find'
        elif len(text_split_semicolon) > 1:
            description = {}
            try:
                for t in text_split_semicolon:
                    paren_start = t.index('(')
                    paren_end = t.index(')')
                    val = t[:paren_start-1]
                    val_split = val.split('-')
                    val_type = t[paren_start+1:paren_end]
                    if len(val_split) > 1:
                        val_array = [float(i) for i in val_split]
                        print(val_array)
                        description[val_type] = val_array
                    elif len(val_split) == 1:
                        val = val_split[0]
                        description[val_type] = float(val)
                    else:
                        description[val_type] = -1
            except:
                return 'Could not find'
        else:
            text_split = text.split('-')
            if len(text_split) == 2:
                description = [float(i) for i in text_split]
            else:
                description = float(text)
    except:
        return 'Could not find'
    
    if breed_name is not None:
        # print(breed_name)
        print('{} -> {}'.format(text, description))

    return description

# 85 (male), 75 (female)
# 100-130 (male), 70-100 (female)
# 75-100 (males); 60-80 (females)
# 6-10 (toy), 10-20 (miniature), 25-35 (standard)

# %%
def parse_life_expectancy(text, breed_name=None):
    text = text.replace(' years', '')
    if '-' in text:
        life_expectancy = text.split('-')
    elif '–' in text:
        life_expectancy = text.split('–')
    else:
        life_expectancy = []

    if type(life_expectancy) == list and len(life_expectancy) == 2:
        if len(life_expectancy) == 2 and '+' in life_expectancy[1]:
            life_expectancy = [life_expectancy[0], 20]
    elif '+' in text:
        life_expectancy = text.replace('+', '')
        life_expectancy = [life_expectancy, 20]
    elif '~' in text:
        approx = int(text.replace('~', ''))
        life_expectancy = [approx-1, approx+1]
    elif text.lower() == 'late teens':
        life_expectancy = [17, 20]
    else:
        try:
            approx = int(text)
            life_expectancy = [approx-1, approx+1]
        except:
            life_expectancy = [-1]

    if breed_name is not None:
        print(breed_name)
        print('{} -> {}'.format(text, life_expectancy))

    life_expectancy = [int(i) for i in life_expectancy]
    return life_expectancy

# %%
def extract_traits(html_text):
    breed_traits = {}
    breed_tabs = html_text.find_all(
        'div', 'tabs__panel-wrap')[1].find_all('div', {'class': 'tabs__tab-panel'})
    for tab in breed_tabs:
        tab_sections = tab.find_all('div', {'class': 'graph-section__inner'})
        for section in tab_sections:
            title = section.find(
                'h4', {'class': 'bar-graph__title'})
            description = section.find(
                'div', {'class': 'bar-graph__text'})
            percentage = section.find('div', {'class': 'bar-graph__section'})
            if title is not None:
                title = title.text
                breed_traits[title] = {}
            else:
                raise Exception('Cannot find title for a title.')
            if description is not None:
                description = description.text
                breed_traits[title]['description'] = description
            else:
                raise Exception('Cannot find description for a description.')
            if percentage is not None:
                percentage = percentage['style']
                percentage = percentage.split(';')
                for p in percentage:
                    if 'width:' in p:
                        percentage = p[-4:].replace('%',
                                                    '').replace('px', '').strip()
                        percentage = int(percentage)
                breed_traits[title]['percentage'] = percentage

    return breed_traits

# %% [markdown]
# # Main

# %%
breed_data = []
for link in breeds_links:
    html = requests.get(link).text
    soup = BeautifulSoup(html, features="html.parser")
    breed_data.append(get_breed_data(soup))
# Out:
# 41.0, 60.0]
# [37.0, 53.0]
# 41-60 (males), 37-53 (females) -> {'males': [41.0, 60.0], 'females': [37.0, 53.0]}
# Bolognese
# 5.5-9 pounds
# 5.5-9 -> [5.5, 9.0]
# Border Collie
# 30-55 pounds
# 30-55 -> [30.0, 55.0]
# Border Terrier
# 13-15.5 pounds (male), 11.5-14 pounds (female)
# [13.0, 15.5]
# [11.5, 14.0]
# 13-15.5 (male), 11.5-14 (female) -> {'male': [13.0, 15.5], 'female': [11.5, 14.0]}
# Borzoi
# 75-105 pounds (male), 60-85 pounds (female)
# [75.0, 105.0]
# [60.0, 85.0]
# 75-105 (male), 60-85 (female) -> {'male': [75.0, 105.0], 'female': [60.0, 85.0]}
# Boston Terrier
# 12-25 pounds
# 12-25 -> [12.0, 25.0]
# Bouvier des Flandres
# 70-110 pounds
# 70-110 -> [70.0, 110.0]
# Boxer
# 65-80 pounds (male), females are about 15 pounds less than male
# [65.0, 80.0]
# Boykin Spaniel
# 30-40 pounds (male), 25-35 pounds (female)
# [30.0, 40.0]
# [25.0, 35.0]
# 30-40 (male), 25-35 (female) -> {'male': [30.0, 40.0], 'female': [25.0, 35.0]}
# Bracco Italiano
# 55-90 pounds
# 55-90 -> [55.0, 90.0]
# Braque du Bourbonnais
# 35-53 pounds
# 35-53 -> [35.0, 53.0]
# Braque Francais Pyrenean
# 40-55 pounds
# 40-55 -> [40.0, 55.0]
# Briard
# 55-100 pounds
# 55-100 -> [55.0, 100.0]
# Brittany
# 30-40 pounds
# 30-40 -> [30.0, 40.0]
# Broholmer
# 90-150 pounds
# 90-150 -> [90.0, 150.0]
# Brussels Griffon
# 8-10 pounds
# 8-10 -> [8.0, 10.0]
# Bull Terrier
# 50-70 pounds
# 50-70 -> [50.0, 70.0]
# Bulldog
# 50 pounds (male), 40 pounds (female)
# 50 (male), 40 (female) -> {'male': 50.0, 'female': 40.0}
# Bullmastiff
# 110-130 pounds (male), 100-120 pounds (female)
# [110.0, 130.0]
# [100.0, 120.0]
# 110-130 (male), 100-120 (female) -> {'male': [110.0, 130.0], 'female': [100.0, 120.0]}
# Cairn Terrier
# 14 pounds (male), 13 pounds (female)
# 14 (male), 13 (female) -> {'male': 14.0, 'female': 13.0}
# Canaan Dog
# 45-55 pounds (male), 35-45 pounds (female)
# [45.0, 55.0]
# [35.0, 45.0]
# 45-55 (male), 35-45 (female) -> {'male': [45.0, 55.0], 'female': [35.0, 45.0]}
# Cane Corso
# Proportionate to height
# Cardigan Welsh Corgi
# 30-38 pounds (male), 25-34 pounds (female)
# [30.0, 38.0]
# [25.0, 34.0]
# 30-38 (male), 25-34 (female) -> {'male': [30.0, 38.0], 'female': [25.0, 34.0]}
# Carolina Dog
# 30-55 pounds
# 30-55 -> [30.0, 55.0]
# Catahoula Leopard Dog
# 50-95 pounds
# 50-95 -> [50.0, 95.0]
# Caucasian Shepherd Dog
# 99-170 pounds
# 99-170 -> [99.0, 170.0]
# Cavalier King Charles Spaniel
# 13-18 pounds
# 13-18 -> [13.0, 18.0]
# Central Asian Shepherd Dog
# Minimum: 88-110 pounds
# 88-110 -> [88.0, 110.0]
# Cesky Terrier
# 14-24 pounds
# 14-24 -> [14.0, 24.0]
# Chesapeake Bay Retriever
# 65-80 pounds (male), 55-70 pounds (female)
# [65.0, 80.0]
# [55.0, 70.0]
# 65-80 (male), 55-70 (female) -> {'male': [65.0, 80.0], 'female': [55.0, 70.0]}
# Chihuahua
# not exceeding 6 pounds
# Chinese Crested
# 8-12 pounds
# 8-12 -> [8.0, 12.0]
# Chinese Shar-Pei
# 45-60 pounds
# 45-60 -> [45.0, 60.0]
# Chinook
# 55-90 pounds (male), 50-65 pounds (female)
# [55.0, 90.0]
# [50.0, 65.0]
# 55-90 (male), 50-65 (female) -> {'male': [55.0, 90.0], 'female': [50.0, 65.0]}
# Chow Chow
# 45-70 pounds
# 45-70 -> [45.0, 70.0]
# Cirneco dell’Etna
# 22-26 pounds (male), 17-22 pounds (female)
# [22.0, 26.0]
# [17.0, 22.0]
# 22-26 (male), 17-22 (female) -> {'male': [22.0, 26.0], 'female': [17.0, 22.0]}
# Clumber Spaniel
# 70-85 pounds (male), 55-70 pounds (female)
# [70.0, 85.0]
# [55.0, 70.0]
# 70-85 (male), 55-70 (female) -> {'male': [70.0, 85.0], 'female': [55.0, 70.0]}
# Cocker Spaniel
# 25-30 pounds (male), 20-25 pounds (female)
# [25.0, 30.0]
# [20.0, 25.0]
# 25-30 (male), 20-25 (female) -> {'male': [25.0, 30.0], 'female': [20.0, 25.0]}
# Collie
# 60-75 pounds (male), 50-65 pounds (female)
# [60.0, 75.0]
# [50.0, 65.0]
# 60-75 (male), 50-65 (female) -> {'male': [60.0, 75.0], 'female': [50.0, 65.0]}
# Coton de Tulear
# 9-15 pounds (male), 8-13 pounds (female)
# [9.0, 15.0]
# [8.0, 13.0]
# 9-15 (male), 8-13 (female) -> {'male': [9.0, 15.0], 'female': [8.0, 13.0]}
# Croatian Sheepdog
# 29-44 pounds
# 29-44 -> [29.0, 44.0]
# Curly-Coated Retriever
# 60-95 pounds
# 60-95 -> [60.0, 95.0]
# Czechoslovakian Vlcak
# Minimum: 44-57 pounds
# 44-57 -> [44.0, 57.0]
# Dachshund
# 16-32 pounds (standard), 11 pounds & under (miniature)
# Dalmatian
# 45-70 pounds
# 45-70 -> [45.0, 70.0]
# Dandie Dinmont Terrier
# 18-24 pounds
# 18-24 -> [18.0, 24.0]
# Danish-Swedish Farmdog
# 15-20 pounds
# 15-20 -> [15.0, 20.0]
# Deutscher Wachtelhund
# 40-55 pounds
# 40-55 -> [40.0, 55.0]
# Doberman Pinscher
# 75-100 pounds (male), 60-90 pounds (female)
# [75.0, 100.0]
# [60.0, 90.0]
# 75-100 (male), 60-90 (female) -> {'male': [75.0, 100.0], 'female': [60.0, 90.0]}
# Dogo Argentino
# 88-100 pounds (male), 88-95 pounds (female)
# [88.0, 100.0]
# [88.0, 95.0]
# 88-100 (male), 88-95 (female) -> {'male': [88.0, 100.0], 'female': [88.0, 95.0]}
# Dogue de Bordeaux
# 110 pounds & up (male), 99 pounds & up (female)
# Drentsche Patrijshond
# 48-73 pounds
# 48-73 -> [48.0, 73.0]
# Drever
# 35-40 pounds
# 35-40 -> [35.0, 40.0]
# Dutch Shepherd
# 42-75 pounds
# 42-75 -> [42.0, 75.0]
# English Cocker Spaniel
# 28-34 pounds (male), 26-32 pounds (female)
# [28.0, 34.0]
# [26.0, 32.0]
# 28-34 (male), 26-32 (female) -> {'male': [28.0, 34.0], 'female': [26.0, 32.0]}
# English Foxhound
# 60-75 pounds
# 60-75 -> [60.0, 75.0]
# English Setter
# 65-80 pounds (male), 45-55 pounds (female)
# [65.0, 80.0]
# [45.0, 55.0]
# 65-80 (male), 45-55 (female) -> {'male': [65.0, 80.0], 'female': [45.0, 55.0]}
# English Springer Spaniel
# 50 pounds (male), 40 pounds (female)
# 50 (male), 40 (female) -> {'male': 50.0, 'female': 40.0}
# English Toy Spaniel
# 8-14 pounds
# 8-14 -> [8.0, 14.0]
# Entlebucher Mountain Dog
# 50-65 pounds (male), 40-55 pounds (female)
# [50.0, 65.0]
# [40.0, 55.0]
# 50-65 (male), 40-55 (female) -> {'male': [50.0, 65.0], 'female': [40.0, 55.0]}
# Estrela Mountain Dog
# 77-132 pounds
# 77-132 -> [77.0, 132.0]
# Eurasier
# 40-70 pounds
# 40-70 -> [40.0, 70.0]
# Field Spaniel
# 35-50 pounds
# 35-50 -> [35.0, 50.0]
# Finnish Lapphund
# 33-53 pounds
# 33-53 -> [33.0, 53.0]
# Finnish Spitz
# 25-33 pounds (male), 20-28 pounds (female)
# [25.0, 33.0]
# [20.0, 28.0]
# 25-33 (male), 20-28 (female) -> {'male': [25.0, 33.0], 'female': [20.0, 28.0]}
# Flat-Coated Retriever
# 60-70 pounds
# 60-70 -> [60.0, 70.0]
# French Bulldog
# under 28 pounds
# French Spaniel
# 50-60 pounds
# 50-60 -> [50.0, 60.0]
# German Longhaired Pointer
# 55-80 pounds
# 55-80 -> [55.0, 80.0]
# German Pinscher
# 25-45 pounds
# 25-45 -> [25.0, 45.0]
# German Shepherd Dog
# 65-90 pounds (male), 50-70 pounds (female)
# [65.0, 90.0]
# [50.0, 70.0]
# 65-90 (male), 50-70 (female) -> {'male': [65.0, 90.0], 'female': [50.0, 70.0]}
# German Shorthaired Pointer
# 55-70 pounds (male), 45-60 pounds (female)
# [55.0, 70.0]
# [45.0, 60.0]
# 55-70 (male), 45-60 (female) -> {'male': [55.0, 70.0], 'female': [45.0, 60.0]}
# German Spitz
# 24-26 pounds
# 24-26 -> [24.0, 26.0]
# German Wirehaired Pointer
# 50-70 pounds
# 50-70 -> [50.0, 70.0]
# Giant Schnauzer
# 60-85 pounds (male), 55-75 pounds (female)
# [60.0, 85.0]
# [55.0, 75.0]
# 60-85 (male), 55-75 (female) -> {'male': [60.0, 85.0], 'female': [55.0, 75.0]}
# Glen of Imaal Terrier
# 32-40 pounds
# 32-40 -> [32.0, 40.0]
# Golden Retriever
# 65-75 pounds (male), 55-65 pounds (female)
# [65.0, 75.0]
# [55.0, 65.0]
# 65-75 (male), 55-65 (female) -> {'male': [65.0, 75.0], 'female': [55.0, 65.0]}
# Gordon Setter
# 55-80 pounds (male), 45-70 pounds (female)
# [55.0, 80.0]
# [45.0, 70.0]
# 55-80 (male), 45-70 (female) -> {'male': [55.0, 80.0], 'female': [45.0, 70.0]}
# Grand Basset Griffon Vendéen
# 40-45 pounds
# 40-45 -> [40.0, 45.0]
# Great Dane
# 140-175 pounds (male), 110-140 pounds (female)
# [140.0, 175.0]
# [110.0, 140.0]
# 140-175 (male), 110-140 (female) -> {'male': [140.0, 175.0], 'female': [110.0, 140.0]}
# Great Pyrenees
# 100 pounds & up (male), 85 pounds & up (female)
# Greater Swiss Mountain Dog
# 115-140 pounds (male), 85-110 pounds (female)
# [115.0, 140.0]
# [85.0, 110.0]
# 115-140 (male), 85-110 (female) -> {'male': [115.0, 140.0], 'female': [85.0, 110.0]}
# Greyhound
# 65-70 pounds (male), 60-65 pounds (female)
# [65.0, 70.0]
# [60.0, 65.0]
# 65-70 (male), 60-65 (female) -> {'male': [65.0, 70.0], 'female': [60.0, 65.0]}
# Hamiltonstovare
# 40-75 pounds
# 40-75 -> [40.0, 75.0]
# Hanoverian Scenthound
# 79-99 pounds
# 79-99 -> [79.0, 99.0]
# Harrier
# 45-60 pounds
# 45-60 -> [45.0, 60.0]
# Havanese
# 7-13 pounds
# 7-13 -> [7.0, 13.0]
# Hokkaido
# 44-66 pounds
# 44-66 -> [44.0, 66.0]
# Hovawart
# 65-90 pounds
# 65-90 -> [65.0, 90.0]
# Ibizan Hound
# 50 pounds (male), 45 pounds (female)
# 50 (male), 45 (female) -> {'male': 50.0, 'female': 45.0}
# Icelandic Sheepdog
# 30 pounds (male), 25 pounds (female)
# 30 (male), 25 (female) -> {'male': 30.0, 'female': 25.0}
# Irish Red and White Setter
# 42-60 pounds (male), 35-50 pounds (female)
# [42.0, 60.0]
# [35.0, 50.0]
# 42-60 (male), 35-50 (female) -> {'male': [42.0, 60.0], 'female': [35.0, 50.0]}
# Irish Setter
# 70 pounds (male), 60 pounds (female)
# 70 (male), 60 (female) -> {'male': 70.0, 'female': 60.0}
# Irish Terrier
# 27 pounds (male), 25 pounds (female)
# 27 (male), 25 (female) -> {'male': 27.0, 'female': 25.0}
# Irish Water Spaniel
# 55-68 pounds (male), 45-58 pounds (female)
# [55.0, 68.0]
# [45.0, 58.0]
# 55-68 (male), 45-58 (female) -> {'male': [55.0, 68.0], 'female': [45.0, 58.0]}
# Irish Wolfhound
# 120 pounds (male), 105 pounds (female)
# 120 (male), 105 (female) -> {'male': 120.0, 'female': 105.0}
# Italian Greyhound
# 7-14 pounds
# 7-14 -> [7.0, 14.0]
# Jagdterrier
# 17-22 pounds
# 17-22 -> [17.0, 22.0]
# Japanese Akitainu
# 65 - 75 pounds (male), 55 -65 pounds (female)
# [65.0, 75.0]
# [55.0, 65.0]
# 65 - 75 (male), 55 -65 (female) -> {'male': [65.0, 75.0], 'female': [55.0, 65.0]}
# Japanese Chin
# 7-11 pounds
# 7-11 -> [7.0, 11.0]
# Japanese Spitz
# 10-25 pounds
# 10-25 -> [10.0, 25.0]
# Japanese Terrier
# 5-10 pounds
# 5-10 -> [5.0, 10.0]
# Jindo
# 30-50 pounds
# 30-50 -> [30.0, 50.0]
# Kai Ken
# 20-40 pounds
# 20-40 -> [20.0, 40.0]
# Karelian Bear Dog
# 44-49 pounds
# 44-49 -> [44.0, 49.0]
# Keeshond
# 35-45 pounds
# 35-45 -> [35.0, 45.0]
# Kerry Blue Terrier
# 33-40 pounds (male), females weigh slightly less than males
# [33.0, 40.0]
# Kishu Ken
# 30-60 pounds
# 30-60 -> [30.0, 60.0]
# Komondor
# 100 pounds or more (male), 80 pounds or more (female)
# Kromfohrlander
# 20-35 pounds
# 20-35 -> [20.0, 35.0]
# Kuvasz
# 100-115 pounds (male), 70-90 pounds (female)
# [100.0, 115.0]
# [70.0, 90.0]
# 100-115 (male), 70-90 (female) -> {'male': [100.0, 115.0], 'female': [70.0, 90.0]}
# Labrador Retriever
# 65-80 pounds (male), 55-70 pounds (female)
# [65.0, 80.0]
# [55.0, 70.0]
# 65-80 (male), 55-70 (female) -> {'male': [65.0, 80.0], 'female': [55.0, 70.0]}
# Lagotto Romagnolo
# 28.5-35 pounds (male), 24-31 pounds (female)
# [28.5, 35.0]
# [24.0, 31.0]
# 28.5-35 (male), 24-31 (female) -> {'male': [28.5, 35.0], 'female': [24.0, 31.0]}
# Lakeland Terrier
# 17 pounds (male), slightly smaller (female)
# Lancashire Heeler
# 9-17 pounds
# 9-17 -> [9.0, 17.0]
# Lapponian Herder
# 70 pounds
# 70 -> 70.0
# Leonberger
# 110-170 pounds (male), 90-140 pounds (female)
# [110.0, 170.0]
# [90.0, 140.0]
# 110-170 (male), 90-140 (female) -> {'male': [110.0, 170.0], 'female': [90.0, 140.0]}
# Lhasa Apso
# 12-18 pounds
# 12-18 -> [12.0, 18.0]
# Löwchen
# 10-15 pounds
# 10-15 -> [10.0, 15.0]
# Maltese
# under 7 pounds
# Manchester Terrier (Standard)
# 12-22 pounds
# 12-22 -> [12.0, 22.0]
# Manchester Terrier (Toy)
# under 12 pounds
# Mastiff
# 160-230 pounds (male), 120-170 pounds (female)
# [160.0, 230.0]
# [120.0, 170.0]
# 160-230 (male), 120-170 (female) -> {'male': [160.0, 230.0], 'female': [120.0, 170.0]}
# Miniature American Shepherd
# 20-40 pounds
# 20-40 -> [20.0, 40.0]
# Miniature Bull Terrier
# 18-28 pounds
# 18-28 -> [18.0, 28.0]
# Miniature Pinscher
# 8-10 pounds
# 8-10 -> [8.0, 10.0]
# Miniature Schnauzer
# 11-20 pounds
# 11-20 -> [11.0, 20.0]
# Mountain Cur
# 30-60 pounds
# 30-60 -> [30.0, 60.0]
# Mudi
# 18-29 pounds
# 18-29 -> [18.0, 29.0]
# Neapolitan Mastiff
# 150 pounds (male), 110 pounds (female)
# 150 (male), 110 (female) -> {'male': 150.0, 'female': 110.0}
# Nederlandse Kooikerhondje
# 20-30 pounds
# 20-30 -> [20.0, 30.0]
# Newfoundland
# 130-150 pounds (male), 100-120 pounds (female)
# [130.0, 150.0]
# [100.0, 120.0]
# 130-150 (male), 100-120 (female) -> {'male': [130.0, 150.0], 'female': [100.0, 120.0]}
# Norfolk Terrier
# 11-12 pounds
# 11-12 -> [11.0, 12.0]
# Norrbottenspets
# 20-30 pounds
# 20-30 -> [20.0, 30.0]
# Norwegian Buhund
# 31-40 pounds (male), 26-35 pounds (female)
# [31.0, 40.0]
# [26.0, 35.0]
# 31-40 (male), 26-35 (female) -> {'male': [31.0, 40.0], 'female': [26.0, 35.0]}
# Norwegian Elkhound
# 55 pounds (male), 48 pounds (female)
# 55 (male), 48 (female) -> {'male': 55.0, 'female': 48.0}
# Norwegian Lundehund
# 20-30 pounds
# 20-30 -> [20.0, 30.0]
# Norwich Terrier
# 12 pounds
# 12 -> 12.0
# Nova Scotia Duck Tolling Retriever
# 35-50 pounds
# 35-50 -> [35.0, 50.0]
# Old English Sheepdog
# 60-100 pounds
# 60-100 -> [60.0, 100.0]
# Otterhound
# 115 pounds (male), 80 pounds (female)
# 115 (male), 80 (female) -> {'male': 115.0, 'female': 80.0}
# Papillon
# 5-10 pounds
# 5-10 -> [5.0, 10.0]
# Parson Russell Terrier
# 13-17 pounds
# 13-17 -> [13.0, 17.0]
# Pekingese
# up to 14 pounds
# Pembroke Welsh Corgi
# up to 30 pounds (male), up to 28 pounds (female)
# Perro de Presa Canario
# 84-110 pounds
# 84-110 -> [84.0, 110.0]
# Peruvian Inca Orchid
# 8.5-17.5 pounds (small) 17.5-26.5 pounds (medium) 26.5-55 pounds (large)
# Petit Basset Griffon Vendéen
# 25-40 pounds
# 25-40 -> [25.0, 40.0]
# Pharaoh Hound
# 45-55 pounds
# 45-55 -> [45.0, 55.0]
# Plott Hound
# 50-60 pounds (male), 40-55 pounds (female)
# [50.0, 60.0]
# [40.0, 55.0]
# 50-60 (male), 40-55 (female) -> {'male': [50.0, 60.0], 'female': [40.0, 55.0]}
# Pointer
# 55-75 pounds (male), 45-65 pounds (female)
# [55.0, 75.0]
# [45.0, 65.0]
# 55-75 (male), 45-65 (female) -> {'male': [55.0, 75.0], 'female': [45.0, 65.0]}
# Polish Lowland Sheepdog
# 30-50 pounds
# 30-50 -> [30.0, 50.0]
# Pomeranian
# 3-7 pounds
# 3-7 -> [3.0, 7.0]
# Poodle (Miniature)
# 10-15 pounds
# 10-15 -> [10.0, 15.0]
# Poodle (Standard)
# 60-70 pounds (male), 40-50 pounds (female)
# [60.0, 70.0]
# [40.0, 50.0]
# 60-70 (male), 40-50 (female) -> {'male': [60.0, 70.0], 'female': [40.0, 50.0]}
# Poodle (Toy)
# 4-6 pounds
# 4-6 -> [4.0, 6.0]
# Porcelaine
# 55-62 pounds
# 55-62 -> [55.0, 62.0]
# Portuguese Podengo
# 44-66 pounds (large) 35-44 pounds (medium)
# Portuguese Podengo Pequeno
# 9-13 pounds
# 9-13 -> [9.0, 13.0]
# Portuguese Pointer
# 35-59 pounds
# 35-59 -> [35.0, 59.0]
# Portuguese Sheepdog
# 37.5-59 pounds
# 37.5-59 -> [37.5, 59.0]
# Portuguese Water Dog
# 42-60 pounds (male), 35-50 pounds (female)
# [42.0, 60.0]
# [35.0, 50.0]
# 42-60 (male), 35-50 (female) -> {'male': [42.0, 60.0], 'female': [35.0, 50.0]}
# Pudelpointer
# 45-70 pounds
# 45-70 -> [45.0, 70.0]
# Pug
# 14-18 pounds
# 14-18 -> [14.0, 18.0]
# Puli
# 25-35 pounds
# 25-35 -> [25.0, 35.0]
# Pumi
# 27-29 pounds (male), 22-24 pounds (female)
# [27.0, 29.0]
# [22.0, 24.0]
# 27-29 (male), 22-24 (female) -> {'male': [27.0, 29.0], 'female': [22.0, 24.0]}
# Pyrenean Mastiff
# 120-240 pounds
# 120-240 -> [120.0, 240.0]
# Pyrenean Shepherd
# 15-30 pounds
# 15-30 -> [15.0, 30.0]
# Rafeiro do Alentejo
# 77-132 pounds
# 77-132 -> [77.0, 132.0]
# Rat Terrier
# 10-25 pounds
# 10-25 -> [10.0, 25.0]
# Redbone Coonhound
# 45-70 pounds
# 45-70 -> [45.0, 70.0]
# Rhodesian Ridgeback
# 85 pounds (male), 70 pounds (female)
# 85 (male), 70 (female) -> {'male': 85.0, 'female': 70.0}
# Romanian Mioritic Shepherd Dog
# 100-130 lbs
# Rottweiler
# 95-135 pounds (male), 80-100 pounds (female)
# [95.0, 135.0]
# [80.0, 100.0]
# 95-135 (male), 80-100 (female) -> {'male': [95.0, 135.0], 'female': [80.0, 100.0]}
# Russell Terrier
# 9-15 pounds
# 9-15 -> [9.0, 15.0]
# Russian Toy
# Up to 6.5 pounds
# Russian Tsvetnaya Bolonka
# 4.5-11 pounds
# 4.5-11 -> [4.5, 11.0]
# Saint Bernard
# 140-180 pounds (male), 120-140 pounds (female)
# [140.0, 180.0]
# [120.0, 140.0]
# 140-180 (male), 120-140 (female) -> {'male': [140.0, 180.0], 'female': [120.0, 140.0]}
# Saluki
# 40-65 pounds
# 40-65 -> [40.0, 65.0]
# Samoyed
# 45-65 pounds (male), 35-50 pounds (female)
# [45.0, 65.0]
# [35.0, 50.0]
# 45-65 (male), 35-50 (female) -> {'male': [45.0, 65.0], 'female': [35.0, 50.0]}
# Schapendoes
# 26-55 pounds
# 26-55 -> [26.0, 55.0]
# Schipperke
# 10-16 pounds
# 10-16 -> [10.0, 16.0]
# Scottish Deerhound
# 85-110 pounds (male), 75-95 pounds (female)
# [85.0, 110.0]
# [75.0, 95.0]
# 85-110 (male), 75-95 (female) -> {'male': [85.0, 110.0], 'female': [75.0, 95.0]}
# Scottish Terrier
# 19-22 pounds (male), 18-21 pounds (female)
# [19.0, 22.0]
# [18.0, 21.0]
# 19-22 (male), 18-21 (female) -> {'male': [19.0, 22.0], 'female': [18.0, 21.0]}
# Sealyham Terrier
# 23-24 pounds (male), slightly less (females)
# [23.0, 24.0]
# Segugio Italiano
# 40-60 pounds
# 40-60 -> [40.0, 60.0]
# Shetland Sheepdog
# 15-25 pounds
# 15-25 -> [15.0, 25.0]
# Shiba Inu
# 23 pounds (male), 17 pounds (female)
# 23 (male), 17 (female) -> {'male': 23.0, 'female': 17.0}
# Shih Tzu
# 9-16 pounds
# 9-16 -> [9.0, 16.0]
# Shikoku
# 35-55 pounds
# 35-55 -> [35.0, 55.0]
# Siberian Husky
# 45-60 pounds (male), 35-50 pounds (female)
# [45.0, 60.0]
# [35.0, 50.0]
# 45-60 (male), 35-50 (female) -> {'male': [45.0, 60.0], 'female': [35.0, 50.0]}
# Silky Terrier
# around 10 pounds
# Skye Terrier
# 35-45 pounds (male), slightly lighter (female)
# [35.0, 45.0]
# Sloughi
# 45 - 70 pounds
# 45 - 70 -> [45.0, 70.0]
# Slovakian Wirehaired Pointer
# 50-65 pounds
# 50-65 -> [50.0, 65.0]
# Slovensky Cuvac
# 68-97 pounds
# 68-97 -> [68.0, 97.0]
# Slovensky Kopov
# 33-44 pounds
# 33-44 -> [33.0, 44.0]
# Small Munsterlander
# 40-60 pounds
# 40-60 -> [40.0, 60.0]
# Smooth Fox Terrier
# 18 pounds (male), 15-17 (female)
# [15.0, 17.0]
# 18 (male), 15-17 (female) -> {'male': 18.0, 'female': [15.0, 17.0]}
# Soft Coated Wheaten Terrier
# 35-40 pounds (male), 30-35 pounds (female)
# [35.0, 40.0]
# [30.0, 35.0]
# 35-40 (male), 30-35 (female) -> {'male': [35.0, 40.0], 'female': [30.0, 35.0]}
# Spanish Mastiff
# 140-200 pounds
# 140-200 -> [140.0, 200.0]
# Spanish Water Dog
# 40-49 pounds (male), 31-40 pounds (female)
# [40.0, 49.0]
# [31.0, 40.0]
# 40-49 (male), 31-40 (female) -> {'male': [40.0, 49.0], 'female': [31.0, 40.0]}
# Stabyhoun
# 40-60 pounds
# 40-60 -> [40.0, 60.0]
# Staffordshire Bull Terrier
# 28-38 pounds (male), 24-34 pounds (female)
# [28.0, 38.0]
# [24.0, 34.0]
# 28-38 (male), 24-34 (female) -> {'male': [28.0, 38.0], 'female': [24.0, 34.0]}
# Standard Schnauzer
# 35-50 pounds (male), 30-45 pounds (female)
# [35.0, 50.0]
# [30.0, 45.0]
# 35-50 (male), 30-45 (female) -> {'male': [35.0, 50.0], 'female': [30.0, 45.0]}
# Sussex Spaniel
# 35-45 pounds
# 35-45 -> [35.0, 45.0]
# Swedish Lapphund
# 30-45 pounds
# 30-45 -> [30.0, 45.0]
# Swedish Vallhund
# 20-35 pounds
# 20-35 -> [20.0, 35.0]
# Taiwan Dog
# 26-40 pounds
# 26-40 -> [26.0, 40.0]
# Teddy Roosevelt Terrier
# 8-25 pounds
# 8-25 -> [8.0, 25.0]
# Thai Ridgeback
# 35-75 pounds
# 35-75 -> [35.0, 75.0]
# Tibetan Mastiff
# 90-150 pounds (male), 70-120 pounds (female)
# [90.0, 150.0]
# [70.0, 120.0]
# 90-150 (male), 70-120 (female) -> {'male': [90.0, 150.0], 'female': [70.0, 120.0]}
# Tibetan Spaniel
# 9-15 pounds
# 9-15 -> [9.0, 15.0]
# Tibetan Terrier
# 18-30 pounds (male), slightly smaller (female)
# [18.0, 30.0]
# Tornjak
# 62-110 pounds
# 62-110 -> [62.0, 110.0]
# Tosa
# 100-200 pounds
# 100-200 -> [100.0, 200.0]
# Toy Fox Terrier
# 3.5-7 pounds
# 3.5-7 -> [3.5, 7.0]
# Transylvanian Hound
# Minimum 55 pounds
# Treeing Tennessee Brindle
# 30-50 pounds
# 30-50 -> [30.0, 50.0]
# Treeing Walker Coonhound
# 50-70 pounds
# 50-70 -> [50.0, 70.0]
# Vizsla
# 55-60 pounds (male), 44-55 pounds (female)
# [55.0, 60.0]
# [44.0, 55.0]
# 55-60 (male), 44-55 (female) -> {'male': [55.0, 60.0], 'female': [44.0, 55.0]}
# Weimaraner
# 70-90 pounds (male), 55-75 pounds (female)
# [70.0, 90.0]
# [55.0, 75.0]
# 70-90 (male), 55-75 (female) -> {'male': [70.0, 90.0], 'female': [55.0, 75.0]}
# Welsh Springer Spaniel
# 40-55 pounds (male), 35-50 pounds (female)
# [40.0, 55.0]
# [35.0, 50.0]
# 40-55 (male), 35-50 (female) -> {'male': [40.0, 55.0], 'female': [35.0, 50.0]}
# Welsh Terrier
# 20 pounds, porportionally smaller (female)
# West Highland White Terrier
# 15-20 pounds
# 15-20 -> [15.0, 20.0]
# Wetterhoun
# 50-75 pounds
# 50-75 -> [50.0, 75.0]
# Whippet
# 25-40 pounds
# 25-40 -> [25.0, 40.0]
# Wire Fox Terrier
# 18 pounds (male), 15-17 (female)
# [15.0, 17.0]
# 18 (male), 15-17 (female) -> {'male': 18.0, 'female': [15.0, 17.0]}
# Wirehaired Pointing Griffon
# 50-70 pounds (male), 35-50 pounds (female)
# [50.0, 70.0]
# [35.0, 50.0]
# 50-70 (male), 35-50 (female) -> {'male': [50.0, 70.0], 'female': [35.0, 50.0]}
# Wirehaired Vizsla
# 55-65 pounds (male), 45-55 pounds (female)
# [55.0, 65.0]
# [45.0, 55.0]
# 55-65 (male), 45-55 (female) -> {'male': [55.0, 65.0], 'female': [45.0, 55.0]}
# Working Kelpie
# 28-60 pounds
# 28-60 -> [28.0, 60.0]
# Xoloitzcuintli
# 10-15 pounds (toy), 15-30 pounds (miniature), 30-55 pounds (standard)
# [10.0, 15.0]
# [15.0, 30.0]
# [30.0, 55.0]
# 10-15 (toy), 15-30 (miniature), 30-55 (standard) -> {'toy': [10.0, 15.0], 'miniature': [15.0, 30.0], 'standard': [30.0, 55.0]}
# Yakutian Laika
# 40-55 pounds
# 40-55 -> [40.0, 55.0]
# Yorkshire Terrier
# 7 pounds
# 7 -> 7.0

# %%
with open('data.json', 'w') as outfile:
        json.dump(breed_data, outfile)

# %% [markdown]
# # Debugging

# %%
print(breeds_options)
# Out:
# n>, <option value="https://www.akc.org/dog-breeds/brussels-griffon/">Brussels Griffon</option>, <option value="https://www.akc.org/dog-breeds/bull-terrier/">Bull Terrier</option>, <option value="https://www.akc.org/dog-breeds/bulldog/">Bulldog</option>, <option value="https://www.akc.org/dog-breeds/bullmastiff/">Bullmastiff</option>, <option value="https://www.akc.org/dog-breeds/cairn-terrier/">Cairn Terrier</option>, <option value="https://www.akc.org/dog-breeds/canaan-dog/">Canaan Dog</option>, <option value="https://www.akc.org/dog-breeds/cane-corso/">